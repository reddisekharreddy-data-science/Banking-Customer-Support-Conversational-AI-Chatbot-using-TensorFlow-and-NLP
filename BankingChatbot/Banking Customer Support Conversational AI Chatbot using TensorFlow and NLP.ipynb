# %% [markdown]
# Install required libraries

# %%
# !pip install tensorflow pandas numpy scikit-learn spacy faiss-cpu sentence-transformers joblib
# Out:
# Requirement already satisfied: tensorflow in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (2.20.0)
# Requirement already satisfied: pandas in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: scikit-learn in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: spacy in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (3.8.11)
# Requirement already satisfied: faiss-cpu in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (1.13.2)
# Requirement already satisfied: sentence-transformers in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (5.2.0)
# Requirement already satisfied: joblib in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (1.5.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.8)
# Requirement already satisfied: pillow in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (0.21.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (2.12.4)
# Requirement already satisfied: jinja2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: filelock in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.9.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
# !pip install tensorflow pandas numpy scikit-learn spacy faiss-cpu sentence-transformers joblib
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: tensorflow in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (2.20.0)
# Requirement already satisfied: pandas in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: scikit-learn in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: spacy in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (3.8.11)
# Requirement already satisfied: faiss-cpu in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (1.13.2)
# Requirement already satisfied: sentence-transformers in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (5.2.0)
# Requirement already satisfied: joblib in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (1.5.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.8)
# Requirement already satisfied: pillow in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (0.21.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (2.12.4)
# Requirement already satisfied: jinja2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: filelock in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.9.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 3.3 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.6/12.8 MB 3.7 MB/s eta 0:00:04
#      -------- ------------------------------- 2.6/12.8 MB 4.1 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.7/12.8 MB 4.4 MB/s eta 0:00:03
#      --------------- ------------------------ 5.0/12.8 MB 4.7 MB/s eta 0:00:02
#      ------------------- -------------------- 6.3/12.8 MB 5.0 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.6/12.8 MB 5.2 MB/s eta 0:00:02
#      --------------------------- ------------ 8.9/12.8 MB 5.4 MB/s eta 0:00:01
#      ------------------------------- -------- 10.2/12.8 MB 5.4 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 5.6 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 5.6 MB/s  0:00:02
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (2.20.1)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.13.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.5)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.8)
# Requirement already satisfied: pillow in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (14.2.0)
# Requirement already satisfied: namex in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\reddy sekhar\appdata\local\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.2)

# %%
import pandas as pd
import numpy as np
import joblib
import faiss
import pickle
import spacy
import tensorflow as tf
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Reddy Sekhar\AppData\Local\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# WARNING:tensorflow:From C:\Users\Reddy Sekhar\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Load dataset

# %%
df = pd.read_csv("BankFAQs.csv")
df.head()
# Out:
#                                             Question  \
# 0  What are the documents required for opening a ...
# 1  Can I transfer my Current Account from one bra...
# 2  My present status is NRI. What extra documents...
# 3  What are the documents required for opening a ...
# 4  What documents are required to change the addr...
#
#                                               Answer     Class
# 0  Following documents are required to open a Cur...  accounts
# 1  Yes, Current Accounts can be transferred from ...  accounts
# 2  NRI/PIO can open the proprietorship/partnershi...  accounts
# 3  Following documents are required for opening a...  accounts
# 4  Following documents are required to change the...  accounts

# %%
#Prepare texts and labels
texts = df["Question"].astype(str).tolist()
answers = df["Answer"].astype(str).tolist()
labels = df["Class"].astype(str).tolist()

# %%
# Label-encode intents
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(labels)
joblib.dump(label_encoder, "label_encoder.pkl")
len(label_encoder.classes_), label_encoder.classes_[:10]
# Out:
# (7,
#  array(['accounts', 'cards', 'fundstransfer', 'insurance', 'investments',
#         'loans', 'security'], dtype='<U13'))

# %%
# Tokenization & Padding (TensorFlow/Keras)
vocab_size = 12000
max_len = 40
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
joblib.dump(tokenizer, "tokenizer.pkl")
sequences = tokenizer.texts_to_sequences(texts)
padded = pad_sequences(sequences, maxlen=max_len, padding="post")

# %%
# Train–test split
X_train, X_test, y_train, y_test = train_test_split(padded, y, test_size=0.2, random_state=42, stratify=y)

# %%
# Build TensorFlow/Keras model
model = Sequential()
model.add(Embedding(vocab_size, 128, input_length=max_len))
model.add(Bidirectional(LSTM(128)))
model.add(Dropout(0.3))
model.add(Dense(64, activation="relu"))
model.add(Dense(len(np.unique(y)), activation="softmax"))
model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train model
history = model.fit(X_train,y_train,validation_split=0.2,epochs=6,batch_size=32,verbose=1)
# Out:
# Epoch 1/6
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.2875 - loss: 1.7293 - val_accuracy: 0.4507 - val_loss: 1.6007
# Epoch 2/6
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.5326 - loss: 1.3158 - val_accuracy: 0.6937 - val_loss: 1.0163
# Epoch 3/6
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.7522 - loss: 0.7431 - val_accuracy: 0.7852 - val_loss: 0.6700
# Epoch 4/6
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.8739 - loss: 0.3943 - val_accuracy: 0.8380 - val_loss: 0.5060
# Epoch 5/6
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9224 - loss: 0.2574 - val_accuracy: 0.8521 - val_loss: 0.5063
# Epoch 6/6
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9515 - loss: 0.1770 - val_accuracy: 0.8592 - val_loss: 0.6237

# %%
# Evaluate intent classifier
y_pred = np.argmax(model.predict(X_test), axis=1)
print(classification_report(y_test,y_pred,target_names=label_encoder.classes_))
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
#                precision    recall  f1-score   support
#
#      accounts       0.95      0.86      0.90        63
#         cards       0.78      0.96      0.86        81
# fundstransfer       0.00      0.00      0.00         3
#     insurance       0.94      0.94      0.94        94
#   investments       0.48      0.43      0.45        28
#         loans       0.96      0.92      0.94        75
#      security       0.71      0.45      0.56        11
#
#      accuracy                           0.86       355
#     macro avg       0.69      0.65      0.66       355
#  weighted avg       0.86      0.86      0.86       355

# %%
# Save intent model
model.save("intent_keras.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow_hub as hub
import numpy as np
import faiss
import pickle

# 1) Take answers from your dataset
answers = df["Answer"].astype(str).tolist()

# 2) Load Universal Sentence Encoder
use_model = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# 3) Embed answers
embeddings = use_model(answers).numpy()

# 4) Build FAISS index with correct dimension (512)
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings.astype("float32"))

# 5) Save new index and answers
faiss.write_index(index, "faq_index.faiss")

with open("faq_answers.pkl", "wb") as f:
    pickle.dump(answers, f)

print("FAISS index rebuilt successfully using USE embeddings.")
# Out:
# WARNING:tensorflow:From C:\Users\Reddy Sekhar\AppData\Local\anaconda3\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From C:\Users\Reddy Sekhar\AppData\Local\anaconda3\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From C:\Users\Reddy Sekhar\AppData\Local\anaconda3\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From C:\Users\Reddy Sekhar\AppData\Local\anaconda3\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# FAISS index rebuilt successfully using USE embeddings.

# %%
# Load components for chatbot
nlp = spacy.load("en_core_web_sm")
intent_model = tf.keras.models.load_model("intent_keras.h5")
tokenizer = joblib.load("tokenizer.pkl")
label_encoder = joblib.load("label_encoder.pkl")
faq_index = faiss.read_index("faq_index.faiss")
answers = pickle.load(open("faq_answers.pkl", "rb"))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Define chatbot functions
def predict_intent(text):
    seq = tokenizer.texts_to_sequences([text])
    pad = pad_sequences(seq, maxlen=max_len, padding="post")
    pred = np.argmax(intent_model.predict(pad), axis=1)[0]
    return label_encoder.inverse_transform([pred])[0]

def get_entities(text):
    doc = nlp(text)
    return [(ent.text, ent.label_) for ent in doc.ents]

def rag_answer(text):
    query_emb = rag_model.encode([text])
    distances, indices = faq_index.search(np.array(query_emb).astype("float32"), k=1)
    return answers[indices[0][0]]

def chatbot_reply(user_input):
    intent = predict_intent(user_input)
    ents = get_entities(user_input)
    ans = rag_answer(user_input)

    print("Detected Intent:", intent)
    print("Entities:", ents)
    print("Response:", ans)

# %%
import tensorflow_hub as hub
import faiss
import pickle
import numpy as np

# Load Universal Sentence Encoder
rag_model = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# Load FAISS index and answers saved earlier
faq_index = faiss.read_index("faq_index.faiss")

with open("faq_answers.pkl", "rb") as f:
    answers = pickle.load(f)

def rag_answer(text):
    # embed query using USE
    query_emb = rag_model([text]).numpy()
    
    # search in FAISS
    distances, indices = faq_index.search(query_emb.astype("float32"), k=1)
    
    # return top answer
    return answers[indices[0][0]]

# %%
# Test chatbot
chatbot_reply("How to open a current account?")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 815ms/step
# Detected Intent: accounts
# Entities: []
# Response: The initial deposit amount to open a Flexi Current account is Rs.75,000.

# %%
chatbot_reply("Documents required for KYC?")
chatbot_reply("How can I transfer my account to another branch?")
chatbot_reply("What are branch timings?")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Detected Intent: investments
# Entities: [('KYC', 'ORG')]
# Response: There no need for any documents to be submitted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Detected Intent: accounts
# Entities: []
# Response: Following is the process to be followed to transfer your account from one branch to another: An account transfer form, signed by all applicants, given at any of our branches. We recommend that you submit the form at the branch that you want your account transferred to. There will be no change in your account number. You can continue to use your existing chequebook, debit card etc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Detected Intent: investments
# Entities: []
# Response: Yes, Current Accounts can be transferred from one branch to another. However, there are certain restrictions. Please visit your nearest branch for details.
